# %% [markdown]
# video link:
#
# https://drive.google.com/file/d/1kD9rjDo4noZn84T-oHwcOESSWPHqXpmO/view?usp=sharing

# %% [markdown]
# # Introduction to Pytorch
#
# PyTorch is a machine learning framework produced by Facebook in October 2016. It is open source, and is based on the popular Torch library. PyTorch is designed to provide good flexibility and high speeds for deep neural network implementation.
#
#
# # **Note that the best way to learn more is to read the documentation for each function**
#
#
# Pytorch doc:
#
# https://pytorch.org/docs/stable/index.html

# %% [markdown]
# ![pytorch_1-1024x289.png](data:image/png;base64,...)

# %% [markdown]
# # Tensor

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# What are the differences between pytorch and numpy?
#
# **[PyTorch vs NumPy](https://www.kaggle.com/code/amirmotefaker/pytorch-vs-numpy)**

# %%
a = [i for i in range(5)]
print(a)
print(type(a))
# Out:
# [0, 1, 2, 3, 4]
# <class 'list'>

# %%
# turn list to tensor
b = torch.tensor(a,dtype=torch.float32) # dtype=torch.float32
print(b)
print(b.shape)
print(b.device)
print(b.dtype)
# Out:
# tensor([0., 1., 2., 3., 4.])
# torch.Size([5])
# cpu
# torch.float32

# %%
# bumpy array
c = np.random.normal(0,2,size=(1,5))
c
# Out:
# array([[-1.52284791, -1.78770622,  2.84852957, -2.35036292,  1.6244928 ]])

# %%
# turn array numpy to tensor
d = torch.from_numpy(c)
d
# Out:
# tensor([[-1.5228, -1.7877,  2.8485, -2.3504,  1.6245]], dtype=torch.float64)

# %%
# turn tensor to numpy
e = d.numpy()
e
# Out:
# array([[-1.52284791, -1.78770622,  2.84852957, -2.35036292,  1.6244928 ]])

# %%
# add and sub and div
d = torch.rand(1,5)
print(d)

add = torch.add(d, 20)
print(add)

sub = torch.sub(d, 0.8)
print(sub)

div = torch.div(d, 2)
print(div)
# Out:
# tensor([[0.3480, 0.0692, 0.8895, 0.6166, 0.8826]])
# tensor([[20.3480, 20.0692, 20.8895, 20.6166, 20.8826]])
# tensor([[-0.4520, -0.7308,  0.0895, -0.1834,  0.0826]])
# tensor([[0.1740, 0.0346, 0.4447, 0.3083, 0.4413]])

# %%
# slicing
d = torch.rand(3,5)
print(d)
print(d[:,2])
print(d[1,1])
# Out:
# tensor([[0.5837, 0.9788, 0.9280, 0.5438, 0.7499],
#         [0.5390, 0.6097, 0.5184, 0.2171, 0.5424],
#         [0.3099, 0.1855, 0.2043, 0.0845, 0.1678]])
# tensor([0.9280, 0.5184, 0.2043])
# tensor(0.6097)

# %%
a = torch.tensor([[1, 2],[3, 4]])
print(a)
print(a.shape)
# Out:
# tensor([[1, 2],
#         [3, 4]])
# torch.Size([2, 2])

# %%
torch.random.manual_seed(5)

# %%
a = torch.randint(3,10,(3,5))
a
# Out:
# tensor([[4, 8, 5, 6, 9],
#         [4, 4, 6, 8, 7],
#         [3, 9, 7, 5, 6]])

# %%
a.T
# Out:
# tensor([[4, 4, 3],
#         [8, 4, 9],
#         [5, 6, 7],
#         [6, 8, 5],
#         [9, 7, 6]])

# %%
b = torch.reshape(a, (5,3))
b
# Out:
# tensor([[4, 8, 5],
#         [6, 9, 4],
#         [4, 6, 8],
#         [7, 3, 9],
#         [7, 5, 6]])

# %%
c = torch.cat([a,a,a],dim=0)
c
# Out:
# tensor([[4, 8, 5, 6, 9],
#         [4, 4, 6, 8, 7],
#         [3, 9, 7, 5, 6],
#         [4, 8, 5, 6, 9],
#         [4, 4, 6, 8, 7],
#         [3, 9, 7, 5, 6],
#         [4, 8, 5, 6, 9],
#         [4, 4, 6, 8, 7],
#         [3, 9, 7, 5, 6]])

# %%
c = torch.cat([a,a,a],dim=1)
c
# Out:
# tensor([[4, 8, 5, 6, 9, 4, 8, 5, 6, 9, 4, 8, 5, 6, 9],
#         [4, 4, 6, 8, 7, 4, 4, 6, 8, 7, 4, 4, 6, 8, 7],
#         [3, 9, 7, 5, 6, 3, 9, 7, 5, 6, 3, 9, 7, 5, 6]])

# %%
# matrix multipe
torch.matmul(a,a.T)
# Out:
# tensor([[222, 189, 203],
#         [189, 181, 172],
#         [203, 172, 200]])

# %%
a @ a.T
# Out:
# tensor([[222, 189, 203],
#         [189, 181, 172],
#         [203, 172, 200]])

# %%
a.matmul(a.T)
# Out:
# tensor([[222, 189, 203],
#         [189, 181, 172],
#         [203, 172, 200]])

# %%
# elementwise matrix multiple
torch.mul(a,a)
# Out:
# tensor([[16, 64, 25, 36, 81],
#         [16, 16, 36, 64, 49],
#         [ 9, 81, 49, 25, 36]])

# %%
a * a
# Out:
# tensor([[16, 64, 25, 36, 81],
#         [16, 16, 36, 64, 49],
#         [ 9, 81, 49, 25, 36]])

# %%
a.mul(a)
# Out:
# tensor([[16, 64, 25, 36, 81],
#         [16, 16, 36, 64, 49],
#         [ 9, 81, 49, 25, 36]])

# %%
print(torch.argmax(a))
print(torch.max(a).item())
print(torch.sum(a))
print(torch.abs(a))
# .item()
# Out:
# tensor(4)
# 9
# tensor(91)
# tensor([[4, 8, 5, 6, 9],
#         [4, 4, 6, 8, 7],
#         [3, 9, 7, 5, 6]])

# %%
a1 = torch.randint(3,10,(3,5))
a1
# Out:
# tensor([[5, 7, 8, 9, 8],
#         [6, 4, 3, 7, 4],
#         [3, 4, 6, 9, 8]])

# %%
a2 = torch.randint(3,10,(3,5))
a2
# Out:
# tensor([[6, 8, 8, 6, 5],
#         [8, 8, 8, 7, 3],
#         [5, 4, 5, 9, 5]])

# %%
torch.eq(a1,a2) # same dimensions
# Out:
# tensor([[False, False,  True, False, False],
#         [False, False, False,  True, False],
#         [False,  True, False,  True, False]])

# %%
torch.save(a,'weight.pt')

# %%
torch.load('/content/weight.pt')
# Out:
# tensor([[4, 8, 5, 6, 9],
#         [4, 4, 6, 8, 7],
#         [3, 9, 7, 5, 6]])

# %% [markdown]
# you can use numpy for generating random numbers and then turn them into torch tensor

# %%
a.device
# Out:
# device(type='cpu')

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# for RuntimeError search STACK OVERFLOW

# %%
# the CUDA tool is a development environment for creating high performance GPU accelerated aplications
# that for this you need an NVIDIA GPU on your machine
a = a.to('cuda')

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torchvision
from torchvision import datasets, transforms
from torch import nn, optim
import cv2
from tqdm import tqdm

# %%
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print("Device", device)
# Out:
# Device cpu

# %% [markdown]
# Useful link for Pytorch Transforms:
#
# [Pytorch Transforms](https://pytorch.org/vision/stable/transforms.html)

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,)),
])

# %% [markdown]
# Useful link for Pytorch Dataset:
#
# **Be sure to read how to create a custom dataset.**
#
# [Pytorch Dataset](https://pytorch.org/vision/main/datasets.html)

# %%
train_path = './mnist/train/'
test_path = './mnist/test/'
trainset = datasets.MNIST(train_path, download=True, train=True, transform=transform)
valset = datasets.MNIST(test_path, download=True, train=False, transform=transform)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1007)>
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to ./mnist/train/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9.91M/9.91M [00:01<00:00, 7.09MB/s]
# Extracting ./mnist/train/MNIST/raw/train-images-idx3-ubyte.gz to ./mnist/train/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1007)>
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to ./mnist/train/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 607kB/s]
# Extracting ./mnist/train/MNIST/raw/train-labels-idx1-ubyte.gz to ./mnist/train/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1007)>
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to ./mnist/train/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 5.65MB/s]
# Extracting ./mnist/train/MNIST/raw/t10k-images-idx3-ubyte.gz to ./mnist/train/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1007)>
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to ./mnist/train/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 3.76MB/s]
# Extracting ./mnist/train/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./mnist/train/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1007)>
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to ./mnist/test/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 21.8MB/s]
# Extracting ./mnist/test/MNIST/raw/train-images-idx3-ubyte.gz to ./mnist/test/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1007)>
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to ./mnist/test/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 615kB/s]
# Extracting ./mnist/test/MNIST/raw/train-labels-idx1-ubyte.gz to ./mnist/test/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1007)>
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to ./mnist/test/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 4.60MB/s]
# Extracting ./mnist/test/MNIST/raw/t10k-images-idx3-ubyte.gz to ./mnist/test/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1007)>
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to ./mnist/test/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 4.38MB/s]
# Extracting ./mnist/test/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./mnist/test/MNIST/raw

# %%
trainset
# Out:
# Dataset MNIST
#     Number of datapoints: 60000
#     Root location: ./mnist/train/
#     Split: Train
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                Normalize(mean=(0.5,), std=(0.5,))
#            )

# %%
trainset.class_to_idx
# Out:
# {'0 - zero': 0,
#  '1 - one': 1,
#  '2 - two': 2,
#  '3 - three': 3,
#  '4 - four': 4,
#  '5 - five': 5,
#  '6 - six': 6,
#  '7 - seven': 7,
#  '8 - eight': 8,
#  '9 - nine': 9}

# %%
for option in dir(trainset):
    if option[0] != '_':
        print(option)
# Out:
# class_to_idx
# classes
# data
# download
# extra_repr
# mirrors
# processed_folder
# raw_folder
# resources
# root
# target_transform
# targets
# test_data
# test_file
# test_labels
# train
# train_data
# train_labels
# training_file
# transform
# transforms

# %%
trainset.class_to_idx
# Out:
# {'0 - zero': 0,
#  '1 - one': 1,
#  '2 - two': 2,
#  '3 - three': 3,
#  '4 - four': 4,
#  '5 - five': 5,
#  '6 - six': 6,
#  '7 - seven': 7,
#  '8 - eight': 8,
#  '9 - nine': 9}

# %%
print(trainset.data.shape)
print(trainset.targets.shape)
print(valset.data.shape)
print(valset.targets.shape)
# Out:
# torch.Size([60000, 28, 28])
# torch.Size([60000])
# torch.Size([10000, 28, 28])
# torch.Size([10000])

# %% [markdown]
# Useful link for Pytorch Dataloader:
#
# [Pytorch Dataloader](https://pytorch.org/vision/main/datasets.html)
#
# [torch.utils.data](https://pytorch.org/docs/stable/data.html)
#
# Optional :
#
# [Writing Custom Datasets, DataLoaders and Transforms](https://pytorch.org/tutorials/beginner/data_loading_tutorial.html)
#
# [Developing Custom PyTorch Dataloaders](https://pytorch.org/tutorials/recipes/recipes/custom_dataset_transforms_loader.html)

# %%
trainloader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True)
valloader = torch.utils.data.DataLoader(valset, batch_size=64, shuffle=False)

# %%
for option in dir(trainloader):
    if option[0] != '_':
        print(option)
# Out:
# batch_sampler
# batch_size
# check_worker_number_rationality
# collate_fn
# dataset
# drop_last
# generator
# multiprocessing_context
# num_workers
# persistent_workers
# pin_memory
# pin_memory_device
# prefetch_factor
# sampler
# timeout
# worker_init_fn

# %%
dataiter = iter(trainloader)
images ,labels = next(dataiter)

print(images.shape)
print(labels.shape)
# Out:
# torch.Size([64, 1, 28, 28])
# torch.Size([64])

# %%
num_of_images = 25
for index in range(1, num_of_images+1):
    plt.subplot(5,5, index)
    plt.axis('off')
    plt.imshow(images[index].numpy().squeeze(),cmap='gray')

# %%
input_size = 28 * 28
hidden_size = [256, 128]
output_size = 10

# %%
model = nn.Sequential(
    nn.Flatten(),
    nn.Linear(input_size, hidden_size[0]),
    nn.ReLU(),
    nn.Linear(hidden_size[0],hidden_size[1]),
    nn.ReLU(),
    nn.Linear(hidden_size[1],output_size)
)

# %%
print(model)
# Out:
# Sequential(
#   (0): Flatten(start_dim=1, end_dim=-1)
#   (1): Linear(in_features=784, out_features=256, bias=True)
#   (2): ReLU()
#   (3): Linear(in_features=256, out_features=128, bias=True)
#   (4): ReLU()
#   (5): Linear(in_features=128, out_features=10, bias=True)
# )

# %%
class MyModel(nn.Module):
    def __init__(self, input_dim, hidden_dims, output_dim):
        super().__init__()
        self.flatten = nn.Flatten()
        self.layers = list()
        self.layers.append(nn.Linear(input_size,hidden_dims[0]))
        self.layers.append(nn.ReLU())
        for idx in range(len(hidden_dims)-1):
            self.layers.append(nn.Linear(hidden_dims[idx],hidden_size[idx+1]))
            self.layers.append(nn.ReLU())
        self.layers.append(nn.Linear(hidden_dims[-1],output_dim))

    def forward(self, X):
        x = self.flatten(X)
        for layer in self.layers:
            x = layer(x)

        return x

# %%
# model with dropout layers:
# this model is just for your test and rest of the code
# is using above one
class MLP(nn.Module):
    def __init__(self, input_dim, hidden_dim1, hidden_dim2, output_dim, dropout_prob=0.5):
        super(MLP, self).__init__()
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(input_dim, hidden_dim1)
        self.dropout1 = nn.Dropout(dropout_prob)
        self.fc2 = nn.Linear(hidden_dim1, hidden_dim2)
        self.dropout2 = nn.Dropout(dropout_prob)
        self.fc3 = nn.Linear(hidden_dim2, output_dim)

    def forward(self, x):
        x = self.flatten(x)
        x = self.dropout1(F.relu(self.fc1(x)))
        x = self.dropout2(F.relu(self.fc2(x)))
        x = self.fc3(x)
        return F.log_softmax(x, dim=1)

# %%
model1 = MyModel(input_size, hidden_size, output_size)

# %%
_ = model.to(device)

# %% [markdown]
# **Useful links:**
#
# **Adam**
#
# [Adam](https://pytorch.org/docs/stable/generated/torch.optim.Adam.html)
#
# **CrossEntropyLoss**
#
# [CrossEntropyLoss](https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html)

# %%
lr = 0.001
n_epochs = 10
val_per_epoch = 1
optimizer = optim.Adam(model.parameters())
criterion = nn.CrossEntropyLoss()

# %%
# adding l2 regularization to our optimizer
# this cell is just for your own test and
# rest is using above loss and optimizer.
optimizer_with_l2 = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-4)  # weight_decay adds L2 regularization

# %%
def accuracy(y_pred, y):
    """
    Calculating the accuracy of given batch.
    input(s):
    y_pred (ndarray): predicted logits or the output of the model.
    y (ndarray): labels
    """
    pred_idx = y_pred.max(1, keepdim=True)[1]
    correct = pred_idx.eq(y.view_as(pred_idx)).sum().item()
    return correct / len(y)

# %%
history = dict()
history['train_loss']= list()
history['train_acc']= list()
history['val_loss']= list()
history['val_acc']= list()

for epoch in range(n_epochs):
    running_loss = 0
    running_acc = 0

    model.train()
    for idx, (X, y) in enumerate(tqdm(trainloader)):
        optimizer.zero_grad()
        X, y = X.to(device), y.to(device)
        y_hat = model(X)
        loss = criterion(y_hat, y)

        # L1 regularization implementation in pytorch
        # notice: don't use l1 reg. with a optimizer with weight_decay

        # L1 regularization coefficient
        # l1_lambda = 0.001

        # l1_norm = sum(param.abs().sum() for param in model.parameters())
        # loss += l1_lambda * l1_norm

        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        running_acc += accuracy(y_hat, y)
    else:
        running_loss = running_loss/ len(trainloader)
        running_acc = running_acc / len(trainloader)
        history['train_loss'].append(running_loss)
        history['train_acc'].append(running_acc)
        print(f'Epoch {epoch+1}/{n_epochs} : training loss: {round(running_loss,3)}, training acc: {round(running_acc*100,2)}')



    if epoch% val_per_epoch == val_per_epoch-1:
        running_loss = 0
        running_acc = 0
        model.eval()
        with torch.no_grad():
            for idx, (X, y) in enumerate(tqdm(valloader)):
                X, y = X.to(device), y.to(device)
                y_hat = model(X)
                loss = criterion(y_hat, y)

                # L1 regularization implementation in pytorch
                # notice: don't use l1 reg. with a optimizer with weight_decay

                # L1 regularization coefficient
                # l1_lambda = 0.001

                # l1_norm = sum(param.abs().sum() for param in model.parameters())
                # loss += l1_lambda * l1_norm

                running_loss += loss.item()
                running_acc += accuracy(y_hat, y)
            else:
                running_loss = running_loss/ len(valloader)
                running_acc = running_acc / len(valloader)
                history['val_loss'].append(running_loss)
                history['val_acc'].append(running_acc)
                print(f'Epoch {epoch+1}/{n_epochs} : validation loss: {round(running_loss,3)}, validation acc: {round(running_acc*100,2)}')
# Out:
# 100%|██████████| 938/938 [00:17<00:00, 52.14it/s]
# Epoch 1/10 : training loss: 0.341, training acc: 89.69
# 100%|██████████| 157/157 [00:02<00:00, 74.11it/s]
# Epoch 1/10 : validation loss: 0.189, validation acc: 94.16
# 100%|██████████| 938/938 [00:14<00:00, 62.91it/s]
# Epoch 2/10 : training loss: 0.155, training acc: 95.23
# 100%|██████████| 157/157 [00:02<00:00, 77.48it/s]
# Epoch 2/10 : validation loss: 0.116, validation acc: 96.52
# 100%|██████████| 938/938 [00:14<00:00, 62.64it/s]
# Epoch 3/10 : training loss: 0.112, training acc: 96.52
# 100%|██████████| 157/157 [00:02<00:00, 75.11it/s]
# Epoch 3/10 : validation loss: 0.107, validation acc: 96.6
# 100%|██████████| 938/938 [00:19<00:00, 49.20it/s]
# Epoch 4/10 : training loss: 0.091, training acc: 97.17
# 100%|██████████| 157/157 [00:02<00:00, 76.08it/s]
# Epoch 4/10 : validation loss: 0.115, validation acc: 96.35
# 100%|██████████| 938/938 [00:14<00:00, 62.71it/s]
# Epoch 5/10 : training loss: 0.078, training acc: 97.46
# 100%|██████████| 157/157 [00:02<00:00, 63.62it/s]
# Epoch 5/10 : validation loss: 0.086, validation acc: 97.3
# 100%|██████████| 938/938 [00:15<00:00, 60.90it/s]
# Epoch 6/10 : training loss: 0.066, training acc: 97.89
# 100%|██████████| 157/157 [00:03<00:00, 47.70it/s]
# Epoch 6/10 : validation loss: 0.077, validation acc: 97.6
# 100%|██████████| 938/938 [00:15<00:00, 61.31it/s]
# Epoch 7/10 : training loss: 0.059, training acc: 98.09
# 100%|██████████| 157/157 [00:02<00:00, 62.73it/s]
# Epoch 7/10 : validation loss: 0.082, validation acc: 97.45
# 100%|██████████| 938/938 [00:14<00:00, 62.72it/s]
# Epoch 8/10 : training loss: 0.052, training acc: 98.25
# 100%|██████████| 157/157 [00:02<00:00, 77.34it/s]
# Epoch 8/10 : validation loss: 0.087, validation acc: 97.4
# 100%|██████████| 938/938 [00:14<00:00, 66.19it/s]
# Epoch 9/10 : training loss: 0.048, training acc: 98.42
# 100%|██████████| 157/157 [00:01<00:00, 79.50it/s]
# Epoch 9/10 : validation loss: 0.09, validation acc: 97.28
# 100%|██████████| 938/938 [00:16<00:00, 57.54it/s]
# Epoch 10/10 : training loss: 0.043, training acc: 98.55
# 100%|██████████| 157/157 [00:02<00:00, 57.87it/s]
# Epoch 10/10 : validation loss: 0.082, validation acc: 97.79

# %%
# This cell is for working with learning rate scheduler and early stopping
# and is just for your test

history = dict()
history['train_loss']= list()
history['train_acc']= list()
history['val_loss']= list()
history['val_acc']= list()


class EarlyStopping:
    def __init__(self, patience=5, verbose=False):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_loss = None
        self.early_stop = False

    def __call__(self, val_loss):
        if self.best_loss is None or val_loss < self.best_loss:
            self.best_loss = val_loss
            self.counter = 0
        else:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True
                if self.verbose:
                    print("Early stopping")

    def should_stop(self):
        return self.early_stop


from torch.optim.lr_scheduler import StepLR
scheduler = StepLR(optimizer, step_size=10, gamma=0.1)

# Early stopping
early_stopping = EarlyStopping(patience=3, verbose=True)


for epoch in range(n_epochs):
    running_loss = 0
    running_acc = 0

    model.train()
    for idx, (X, y) in enumerate(tqdm(trainloader)):
        optimizer.zero_grad()
        X, y = X.to(device), y.to(device)
        y_hat = model(X)
        loss = criterion(y_hat, y)

        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        running_acc += accuracy(y_hat, y)
    else:
        running_loss = running_loss/ len(trainloader)
        running_acc = running_acc / len(trainloader)
        history['train_loss'].append(running_loss)
        history['train_acc'].append(running_acc)
        print(f'Epoch {epoch+1}/{n_epochs} : training loss: {round(running_loss,3)}, training acc: {round(running_acc*100,2)}')



    if epoch% val_per_epoch == val_per_epoch-1:
        running_loss = 0
        running_acc = 0
        model.eval()
        with torch.no_grad():
            for idx, (X, y) in enumerate(tqdm(valloader)):
                X, y = X.to(device), y.to(device)
                y_hat = model(X)
                loss = criterion(y_hat, y)

                running_loss += loss.item()
                running_acc += accuracy(y_hat, y)
            else:
                running_loss = running_loss/ len(valloader)
                running_acc = running_acc / len(valloader)
                history['val_loss'].append(running_loss)
                history['val_acc'].append(running_acc)
                print(f'Epoch {epoch+1}/{n_epochs} : validation loss: {round(running_loss,3)}, validation acc: {round(running_acc*100,2)}')



    # Check for early stopping
    early_stopping(running_loss)
    if early_stopping.should_stop():
      print("Early stopping triggered")
      break

    # Step the scheduler
    scheduler.step()
# Out:
# 100%|██████████| 938/938 [00:19<00:00, 48.45it/s]
# Epoch 1/10 : training loss: 0.339, training acc: 89.82
# 100%|██████████| 157/157 [00:02<00:00, 57.91it/s]
# Epoch 1/10 : validation loss: 0.188, validation acc: 94.21
# 100%|██████████| 938/938 [00:21<00:00, 44.26it/s]
# Epoch 2/10 : training loss: 0.152, training acc: 95.31
# 100%|██████████| 157/157 [00:02<00:00, 64.90it/s]
# Epoch 2/10 : validation loss: 0.113, validation acc: 96.48
# 100%|██████████| 938/938 [00:21<00:00, 43.18it/s]
# Epoch 3/10 : training loss: 0.112, training acc: 96.5
# 100%|██████████| 157/157 [00:02<00:00, 60.46it/s]
# Epoch 3/10 : validation loss: 0.101, validation acc: 96.88
# 100%|██████████| 938/938 [00:21<00:00, 43.85it/s]
# Epoch 4/10 : training loss: 0.09, training acc: 97.21
# 100%|██████████| 157/157 [00:02<00:00, 64.34it/s]
# Epoch 4/10 : validation loss: 0.108, validation acc: 96.39
# 100%|██████████| 938/938 [00:22<00:00, 41.90it/s]
# Epoch 5/10 : training loss: 0.076, training acc: 97.62
# 100%|██████████| 157/157 [00:02<00:00, 62.89it/s]
# Epoch 5/10 : validation loss: 0.094, validation acc: 97.16
# 100%|██████████| 938/938 [00:21<00:00, 44.65it/s]
# Epoch 6/10 : training loss: 0.067, training acc: 97.9
# 100%|██████████| 157/157 [00:02<00:00, 53.48it/s]
# Epoch 6/10 : validation loss: 0.084, validation acc: 97.4
# 100%|██████████| 938/938 [00:21<00:00, 44.34it/s]
# Epoch 7/10 : training loss: 0.063, training acc: 97.93
# 100%|██████████| 157/157 [00:03<00:00, 47.25it/s]
# Epoch 7/10 : validation loss: 0.081, validation acc: 97.4
# 100%|██████████| 938/938 [00:20<00:00, 46.09it/s]
# Epoch 8/10 : training loss: 0.053, training acc: 98.22
# 100%|██████████| 157/157 [00:02<00:00, 56.38it/s]
# Epoch 8/10 : validation loss: 0.08, validation acc: 97.5
# 100%|██████████| 938/938 [00:20<00:00, 44.96it/s]
# Epoch 9/10 : training loss: 0.047, training acc: 98.45
# 100%|██████████| 157/157 [00:02<00:00, 65.05it/s]
# Epoch 9/10 : validation loss: 0.075, validation acc: 97.8
# 100%|██████████| 938/938 [00:21<00:00, 43.94it/s]
# Epoch 10/10 : training loss: 0.045, training acc: 98.52
# 100%|██████████| 157/157 [00:02<00:00, 57.25it/s]
# Epoch 10/10 : validation loss: 0.073, validation acc: 97.9

# %%
plt.title('train loss')
plt.plot(history['train_loss'])
plt.xlabel("epochs")
plt.ylabel("loss")
plt.show()

# %%
plt.title('val loss')
plt.plot(history['val_loss'])
plt.xlabel("epochs")
plt.ylabel("loss")
plt.show()

# %%
plt.title('train acc')
plt.plot(history['train_acc'])
plt.xlabel("epochs")
plt.ylabel("acc")
plt.show()

# %%
plt.title('val acc')
plt.plot(history['val_acc'])
plt.xlabel("epochs")
plt.ylabel("acc")
plt.show()

# %%
images = images.to(device)

# %%
pred = model(images)

# %%
pred[0]
# Out:
# tensor([ -9.1871,  -9.1743,  -6.5286,  -2.9074,  -2.8177, -12.3697, -17.8954,
#           0.5652,  -5.2494,  12.7772], device='cuda:0',
#        grad_fn=<SelectBackward0>)

# %%
labels[0]
# Out:
# tensor(9)

# %% [markdown]
# # Task

# %% [markdown]
# # Now implement a MLP model with desired architecture using Pytorch and train on train data of the preprocessed data of previous workshop.
#
# **Then evaluate model on test data and try to report more informative evaluation measurements like acc, recall, precision, f1 ([source](https://scikit-learn.org/0.15/modules/generated/sklearn.metrics.classification_report.html)) and [confusion matrix](https://scikit-learn.org/1.5/modules/generated/sklearn.metrics.confusion_matrix.html)**
#
# you can even plot confusin matrix ([source](https://medium.com/@dtuk81/confusion-matrix-visualization-fc31e3f30fea))
#
# In this section you have to make decisions on hyper-parameters to prevent overfitting.

# %% [markdown]
# ## TODO

# %%
from imblearn.under_sampling import RandomUnderSampler
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
import numpy as np
from tqdm import tqdm
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cancer_x_train = pd.read_csv('/content/drive/My Drive/cancer_x_train.csv' , index_col=0)
cancer_x_test = pd.read_csv('/content/drive/My Drive/cancer_x_test.csv' , index_col=0)
liver_x_train = pd.read_csv('/content/drive/My Drive/liver_x_train.csv' , index_col=0)
liver_x_test = pd.read_csv('/content/drive/My Drive/liver_x_test.csv' , index_col=0)
cancer_y_train = pd.read_csv('/content/drive/My Drive/cancer_y_train.csv' , index_col=0)
cancer_y_test = pd.read_csv('/content/drive/My Drive/cancer_y_test.csv' , index_col=0)
liver_y_train = pd.read_csv('/content/drive/My Drive/liver_y_train.csv' , index_col=0)
liver_y_test = pd.read_csv('/content/drive/My Drive/liver_y_test.csv' , index_col=0)

# %%
rus = RandomUnderSampler(random_state=0)
liver_x_resampled, liver_y_resampled = rus.fit_resample(liver_x_train, liver_y_train)

rus = RandomUnderSampler(random_state=0)
cancer_x_resampled, cancer_y_resampled = rus.fit_resample(cancer_x_train, cancer_y_train)

# %%
rus = RandomUnderSampler(random_state=0)
liver_x_test_resampled, liver_y_test_resampled = rus.fit_resample(liver_x_test, liver_y_test)

rus = RandomUnderSampler(random_state=0)
cancer_x_test_resampled, cancer_y_test_resampled = rus.fit_resample(cancer_x_test, cancer_y_test)

# %%
class DataPreprocessor:
    def __init__(self, X_resampled, y_resampled, X_test, y_test):
        self.X = np.array(X_resampled)
        self.y = np.array(y_resampled)
        self.X_test = np.array(X_test)
        self.y_test = np.array(y_test)

        self.X_train, self.X_val, self.y_train, self.y_val = train_test_split(self.X, self.y, test_size=0.2, random_state=42)

        self.X_train, self.y_train = torch.Tensor(self.X_train), torch.Tensor(self.y_train)
        self.X_val, self.y_val = torch.Tensor(self.X_val), torch.Tensor(self.y_val)
        self.X_test, self.y_test = torch.Tensor(self.X_test), torch.Tensor(self.y_test)

# %%
class MLP(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(MLP, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.fc2 = nn.Linear(hidden_size, output_size)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = self.sigmoid(self.fc1(x))
        x = self.sigmoid(self.fc2(x))
        return x

# %%
def calculate_loss(output, target):
    criterion = nn.BCELoss()
    loss = criterion(output, target)
    return loss

def calculate_accuracy(output, target):
    predictions = (output > 0.5)
    accuracy = (predictions == target).float().mean()
    return accuracy

# %%
class Trainer:

    def __init__(self, model, train_loader, val_loader, epochs=100, learning_rate=0.1, scheduler_step=30, scheduler_gamma=0.1):
        self.model = model
        self.train_loader = train_loader
        self.val_loader = val_loader
        self.epochs = epochs
        self.criterion = nn.BCELoss()
        self.optimizer = optim.SGD(self.model.parameters(), lr=learning_rate,momentum=0.8)
        self.scheduler = optim.lr_scheduler.StepLR(self.optimizer, step_size=scheduler_step, gamma=scheduler_gamma)
        self.train_losses, self.val_losses = [], []
        self.train_accuracies, self.val_accuracies = [], []
        # dropself.dropout(0.5)

    def train(self):

      for epoch in (range(self.epochs)):

          self.model.train()
          train_loss, train_correct = 0, 0

          for X_batch, y_batch in self.train_loader:
              # print(X_batch.shape,y_batch.shape)
              self.optimizer.zero_grad()
              output = self.model(X_batch)

              loss = calculate_loss(output, y_batch)
              accuracy = calculate_accuracy(output, y_batch)
              # L1 regularization implementation in pytorch
              # notice: don't use l1 reg. with a optimizer with weight_decay

              # L1 regularization coefficient
              # l1_lambda = 0.005

              # l1_norm = sum(param.abs().sum() for param in model.parameters())
              # loss += l1_lambda * l1_norm

              loss.backward()
              self.optimizer.step()

              train_loss += loss.item()
              train_correct += accuracy.item()

          train_loss /= len(self.train_loader)
          train_accuracy = train_correct / len(self.train_loader)
          self.train_losses.append(train_loss)
          self.train_accuracies.append(train_accuracy)

          self.model.eval()
          val_loss, val_correct = 0, 0
          with torch.no_grad():
              for X_batch, y_batch in self.val_loader:
                  output = self.model(X_batch)

                  loss = calculate_loss(output, y_batch)
                  accuracy = calculate_accuracy(output, y_batch)

                  val_loss += loss.item()
                  val_correct += accuracy.item()

          val_loss /= len(self.val_loader)
          val_accuracy = val_correct / len(self.val_loader)
          self.val_losses.append(val_loss)
          self.val_accuracies.append(val_accuracy)

          self.scheduler.step()

          if (epoch + 1) % 10 == 0:
              print(f"Epoch {epoch+1}/{self.epochs}, Train Loss: {train_loss:.4f}, Train Acc: {train_accuracy:.4f}, Val Loss: {val_loss:.4f}, Val Acc: {val_accuracy:.4f}")

    def plot_results(self):

        plt.figure(figsize=(12, 5))
        plt.subplot(1, 2, 1)
        plt.plot(self.train_losses, label='Train')
        plt.plot(self.val_losses, label='Validation')
        plt.title('Loss')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.legend()

        plt.subplot(1, 2, 2)
        plt.plot(self.train_accuracies, label='Train')
        plt.plot(self.val_accuracies, label='Validation')
        plt.title('Accuracy')
        plt.xlabel('Epoch')
        plt.ylabel('Accuracy')
        plt.legend()

        plt.tight_layout()
        plt.show()

class Tester:

    def __init__(self, model, X_test, y_test):
        self.model = model
        self.X_test = X_test
        self.y_test = y_test

    def test(self):

      self.model.eval()
      with torch.no_grad():
          output = self.model(self.X_test)

          test_loss = calculate_loss(output, self.y_test).item()
          test_accuracy = calculate_accuracy(output, self.y_test).item()
          predictions = (output > 0.5).cpu().numpy()
          true_labels = self.y_test.cpu().numpy()

          precision = precision_score(true_labels, predictions)
          recall = recall_score(true_labels, predictions)
          f1 = f1_score(true_labels, predictions)


          print(f"Test Loss: {test_loss:.4f}")
          print(f"Test Accuracy: {test_accuracy:.4f}")
          print(f"Precision: {precision:.4f}")
          print(f"Recall: {recall:.4f}")
          print(f"F1 Score: {f1:.4f}")

          self.plot_confusion_matrix(predictions)

          return output

    def plot_confusion_matrix(self, predictions):
        cm = confusion_matrix(self.y_test, predictions)
        plt.figure(figsize=(6, 4))
        sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=[0, 1], yticklabels=[0, 1])
        plt.xlabel('Predicted')
        plt.ylabel('Actual')
        plt.title('Confusion Matrix')
        plt.show()

# %%
preprocessor = DataPreprocessor(liver_x_resampled, liver_y_resampled, liver_x_test, liver_y_test)

train_data = TensorDataset(preprocessor.X_train, preprocessor.y_train)
val_data = TensorDataset(preprocessor.X_val, preprocessor.y_val)
train_loader = DataLoader(train_data, batch_size=32, shuffle=True)
val_loader = DataLoader(val_data, batch_size=32, shuffle=False)

input_size = preprocessor.X_train.shape[1]
hidden_size = 10
output_size = 1

model = MLP(input_size, hidden_size, output_size)
trainer = Trainer(model, train_loader, val_loader, epochs=100, learning_rate=0.1, scheduler_step=20, scheduler_gamma=0.1)
trainer.train()
# Out:
# Epoch 10/100, Train Loss: 0.6208, Train Acc: 0.6594, Val Loss: 0.6207, Val Acc: 0.7167
# Epoch 20/100, Train Loss: 0.6152, Train Acc: 0.6719, Val Loss: 0.6075, Val Acc: 0.7062
# Epoch 30/100, Train Loss: 0.6130, Train Acc: 0.6687, Val Loss: 0.6063, Val Acc: 0.6854
# Epoch 40/100, Train Loss: 0.5929, Train Acc: 0.6750, Val Loss: 0.6061, Val Acc: 0.6958
# Epoch 50/100, Train Loss: 0.5838, Train Acc: 0.7000, Val Loss: 0.6064, Val Acc: 0.6958
# Epoch 60/100, Train Loss: 0.5791, Train Acc: 0.7125, Val Loss: 0.6064, Val Acc: 0.6958
# Epoch 70/100, Train Loss: 0.5748, Train Acc: 0.7125, Val Loss: 0.6064, Val Acc: 0.6958
# Epoch 80/100, Train Loss: 0.6009, Train Acc: 0.6937, Val Loss: 0.6064, Val Acc: 0.6958
# Epoch 90/100, Train Loss: 0.5957, Train Acc: 0.6937, Val Loss: 0.6064, Val Acc: 0.6958
# Epoch 100/100, Train Loss: 0.5918, Train Acc: 0.7031, Val Loss: 0.6064, Val Acc: 0.6958

# %%
trainer.plot_results()

tester = Tester(model, preprocessor.X_test, preprocessor.y_test)
predictions = tester.test()
# Out:
# Test Loss: 0.6732
# Test Accuracy: 0.5824
# Precision: 0.9735
# Recall: 0.5819
# F1 Score: 0.7284

# %%
preprocessor = DataPreprocessor(cancer_x_resampled, cancer_y_resampled, cancer_x_test, cancer_y_test)

train_data = TensorDataset(preprocessor.X_train, preprocessor.y_train)
val_data = TensorDataset(preprocessor.X_val, preprocessor.y_val)
train_loader = DataLoader(train_data, batch_size=32, shuffle=True)
val_loader = DataLoader(val_data, batch_size=32, shuffle=False)

input_size = preprocessor.X_train.shape[1]
hidden_size = 10
output_size = 1

model = MLP(input_size, hidden_size, output_size)
trainer = Trainer(model, train_loader, val_loader, epochs=100, learning_rate=0.1, scheduler_step=20, scheduler_gamma=0.1)
trainer.train()

trainer.plot_results()

tester = Tester(model, preprocessor.X_test, preprocessor.y_test)
predictions = tester.test()
# Out:
# Epoch 10/100, Train Loss: 0.6777, Train Acc: 0.5898, Val Loss: 0.6846, Val Acc: 0.5938
# Epoch 20/100, Train Loss: 0.6755, Train Acc: 0.6394, Val Loss: 0.6819, Val Acc: 0.6198
# Epoch 30/100, Train Loss: 0.6721, Train Acc: 0.6364, Val Loss: 0.6800, Val Acc: 0.6875
# Epoch 40/100, Train Loss: 0.6724, Train Acc: 0.6210, Val Loss: 0.6798, Val Acc: 0.6875
# Epoch 50/100, Train Loss: 0.6736, Train Acc: 0.6295, Val Loss: 0.6798, Val Acc: 0.6875
# Epoch 60/100, Train Loss: 0.6735, Train Acc: 0.6295, Val Loss: 0.6799, Val Acc: 0.6927
# Epoch 70/100, Train Loss: 0.6724, Train Acc: 0.6424, Val Loss: 0.6799, Val Acc: 0.6927
# Epoch 80/100, Train Loss: 0.6732, Train Acc: 0.6359, Val Loss: 0.6799, Val Acc: 0.6927
# Epoch 90/100, Train Loss: 0.6713, Train Acc: 0.6359, Val Loss: 0.6799, Val Acc: 0.6927
# Epoch 100/100, Train Loss: 0.6727, Train Acc: 0.6359, Val Loss: 0.6799, Val Acc: 0.6927
# Test Loss: 0.6607
# Test Accuracy: 0.7594
# Precision: 0.9179
# Recall: 0.8004
# F1 Score: 0.8551
